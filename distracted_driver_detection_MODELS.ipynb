# %%
# Check if GPU is activated
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ####Mounting gdrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ##Reading the kaggle dataset

# %%
import shutil
shutil.copy("/content/gdrive/MyDrive/project/state-farm-distracted-driver-detection.zip","/content/state-farm-distracted-driver-detection.zip")
# Out:
# '/content/state-farm-distracted-driver-detection.zip'

# %%
! unzip state-farm-distracted-driver-detection.zip -d state-farm-distracted-driver-detection

# %% [markdown]
# ##Image Preprocessing

# %%
#@title
#@title
import os
from numpy import *
from numpy import expand_dims
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import pandas as pd

# !pip install pickle5
import pickle5 as pickle
set_printoptions(threshold=inf)

def preprocessing(image_path):
  global final_dataframe
  try:
    img = cv2.imread(image_path)
  except IOError:
    print("image could not be found")

  # height, width = img.shape

  height = 40
  width = 30
  img = cv2.resize(img, (height, width), interpolation=cv2.INTER_LINEAR)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

  # img = cv2.imread(img)
  #img = color.rgb2gray(img)
  img = img.flatten()
  image_person, image_class = find_person(image_path)
  final_dataframe = final_dataframe.append({'Image_name': image_path.split("/")[-1], 
                                            "Person": image_person, 
                                            "Vector": img, 
                                            "Class": image_class}
                                            ,ignore_index=True)
   
def find_person(image_path):
  global driver_imgs_list
  image_name = image_path.split("/")[-1]
  if(image_name.count('_') > 1):
    temp = image_name.split('_')
    image_name = temp[0] + '_' + temp[1] + '.jpg'
  person_details = driver_imgs_list.loc[driver_imgs_list["img"] == image_name]
  image_person = person_details["subject"].values[0]
  image_class = person_details["classname"].values[0][1:]
  return (image_person, image_class)

def start_processing(c, directory_path):
  final_path = directory_path +"/" +c
  with os.scandir(final_path) as entries:
      for entry in entries:
          path = final_path + '/' + entry.name
          preprocessing(path)
         
  print(c + 'is done')

driver_imgs_list = pd.read_csv('/content/state-farm-distracted-driver-detection/driver_imgs_list.csv')
final_dataframe = pd.DataFrame(columns=['Image_name', 'Person', 'Vector', 'Class'])

directories =  '/content/state-farm-distracted-driver-detection/imgs/train'
classes = ['c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9']
(224,224,3)
for c in classes:
  start_processing(c,directories)

pickle_dataframe = final_dataframe
# suma = zeros(12288, dtype=float)
# for i in pickle_dataframe['Vector']:
#     suma += i
# mean = (suma/pickle_dataframe.shape[0])
# pickle_dataframe['Vector'] = pickle_dataframe['Vector'].apply(lambda x: x-mean)
pickle_dataframe.to_pickle("/content/gdrive/MyDrive/project/knn_val.pkl")
# Out:
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.11)
# c0is done
# c1is done
# c2is done
# c3is done
# c4is done
# c5is done
# c6is done
# c7is done
# c8is done
# c9is done

# %% [markdown]
# #Testing

# %%
#@title Test Data
import os
from numpy import *
from numpy import expand_dims
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import pandas as pd

set_printoptions(threshold=inf)

def preprocessing1(image_path):
    global test_dataframe
    try:
        img = cv2.imread(image_path)
    except IOError:
        print("image could not be found")

    height, width, columns = img.shape

    height = 40
    width = 30
    img = cv2.resize(img, (height, width), interpolation=cv2.INTER_LINEAR)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    img = img.flatten()
    name = image_path.split("/")[-1]
    test_dataframe = test_dataframe.append({'Image_name': name, 
                                            "Vector": img}
                                            ,ignore_index=True)
    print("done printing for ", name)


train_path = '/content/state-farm-distracted-driver-detection/imgs/test' 
test_dataframe = pd.DataFrame(columns=['Image_name', 'Vector'])

with os.scandir(train_path) as entries:
      for entry in entries:
          path = train_path + '/' + entry.name
          preprocessing1(path)
# Out:
# Streaming output truncated to the last 5000 lines.
# done printing for  img_99279.jpg
# done printing for  img_47725.jpg
# done printing for  img_33378.jpg
# done printing for  img_59473.jpg
# done printing for  img_16595.jpg
# done printing for  img_598.jpg
# done printing for  img_76442.jpg
# done printing for  img_17593.jpg
# done printing for  img_36145.jpg
# done printing for  img_15455.jpg
# done printing for  img_72245.jpg
# done printing for  img_14123.jpg
# done printing for  img_71941.jpg
# done printing for  img_42566.jpg
# done printing for  img_31444.jpg
# done printing for  img_89084.jpg
# done printing for  img_94613.jpg
# done printing for  img_41490.jpg
# done printing for  img_68633.jpg
# done printing for  img_1591.jpg
# done printing for  img_66562.jpg
# done printing for  img_96255.jpg
# done printing for  img_475.jpg
# done printing for  img_78535.jpg
# done printing for  img_65464.jpg
# done printing for  img_17074.jpg
# done printing for  img_70638.jpg
# done printing for  img_64974.jpg
# done printing for  img_17224.jpg
# done printing for  img_73431.jpg
# done printing for  img_99022.jpg
# done printing for  img_5744.jpg
# done printing for  img_1192.jpg
# done printing for  img_17940.jpg
# done printing for  img_73492.jpg
# done printing for  img_21244.jpg
# done printing for  img_80056.jpg
# done printing for  img_75832.jpg
# done printing for  img_76606.jpg
# done printing for  img_88091.jpg
# done printing for  img_85733.jpg
# done printing for  img_79862.jpg
# done printing for  img_72860.jpg
# done printing for  img_94827.jpg
# done printing for  img_6080.jpg
# done printing for  img_17637.jpg
# done printing for  img_4586.jpg
# done printing for  img_93443.jpg
# done printing for  img_73592.jpg
# done printing for  img_79439.jpg
# done printing for  img_64992.jpg
# done printing for  img_12387.jpg
# done printing for  img_42201.jpg
# done printing for  img_36655.jpg
# done printing for  img_58525.jpg
# done printing for  img_21590.jpg
# done printing for  img_17491.jpg
# done printing for  img_15665.jpg
# done printing for  img_71352.jpg
# done printing for  img_4204.jpg
# done printing for  img_11099.jpg
# done printing for  img_19605.jpg
# done printing for  img_85125.jpg
# done printing for  img_15169.jpg
# done printing for  img_8344.jpg
# done printing for  img_70063.jpg
# done printing for  img_41466.jpg
# done printing for  img_22269.jpg
# done printing for  img_98038.jpg
# done printing for  img_24272.jpg
# done printing for  img_35938.jpg
# done printing for  img_31206.jpg
# done printing for  img_88047.jpg
# done printing for  img_18153.jpg
# done printing for  img_40882.jpg
# done printing for  img_48917.jpg
# done printing for  img_73077.jpg
# done printing for  img_94276.jpg
# done printing for  img_30009.jpg
# done printing for  img_9028.jpg
# done printing for  img_59026.jpg
# done printing for  img_57114.jpg
# done printing for  img_94282.jpg
# done printing for  img_7140.jpg
# done printing for  img_92933.jpg
# done printing for  img_58437.jpg
# done printing for  img_73352.jpg
# done printing for  img_97593.jpg
# done printing for  img_9855.jpg
# done printing for  img_32723.jpg
# done printing for  img_11028.jpg
# done printing for  img_96881.jpg
# done printing for  img_66653.jpg
# done printing for  img_37654.jpg
# done printing for  img_46482.jpg
# done printing for  img_66796.jpg
# done printing for  img_19352.jpg
# done printing for  img_75742.jpg
# done printing for  img_37264.jpg
# done printing for  img_24530.jpg
# done printing for  img_47865.jpg
# done printing for  img_22670.jpg
# done printing for  img_2223.jpg
# done printing for  img_86862.jpg
# done printing for  img_78819.jpg
# done printing for  img_86202.jpg
# done printing for  img_10212.jpg
# done printing for  img_71734.jpg
# done printing for  img_47314.jpg
# done printing for  img_97186.jpg
# done printing for  img_93170.jpg
# done printing for  img_48667.jpg
# done printing for  img_49297.jpg
# done printing for  img_21311.jpg
# done printing for  img_37374.jpg
# done printing for  img_69222.jpg
# done printing for  img_35489.jpg
# done printing for  img_25067.jpg
# done printing for  img_16873.jpg
# done printing for  img_20972.jpg
# done printing for  img_9962.jpg
# done printing for  img_33690.jpg
# done printing for  img_40007.jpg
# done printing for  img_44968.jpg
# done printing for  img_74487.jpg
# done printing for  img_65339.jpg
# done printing for  img_3982.jpg
# done printing for  img_91991.jpg
# done printing for  img_1056.jpg
# done printing for  img_40830.jpg
# done printing for  img_55743.jpg
# done printing for  img_54446.jpg
# done printing for  img_52157.jpg
# done printing for  img_66793.jpg
# done printing for  img_25682.jpg
# done printing for  img_19292.jpg
# done printing for  img_57990.jpg
# done printing for  img_41484.jpg
# done printing for  img_80164.jpg
# done printing for  img_46548.jpg
# done printing for  img_97239.jpg
# done printing for  img_11673.jpg
# done printing for  img_49066.jpg
# done printing for  img_240.jpg
# done printing for  img_10625.jpg
# done printing for  img_55472.jpg
# done printing for  img_44009.jpg
# done printing for  img_12858.jpg
# done printing for  img_80075.jpg
# done printing for  img_17806.jpg
# done printing for  img_44033.jpg
# done printing for  img_15254.jpg
# done printing for  img_21438.jpg
# done printing for  img_60752.jpg
# done printing for  img_6879.jpg
# done printing for  img_71638.jpg
# done printing for  img_49959.jpg
# done printing for  img_24695.jpg
# done printing for  img_57774.jpg
# done printing for  img_92549.jpg
# done printing for  img_99817.jpg
# done printing for  img_77387.jpg
# done printing for  img_20142.jpg
# done printing for  img_98675.jpg
# done printing for  img_86177.jpg
# done printing for  img_18318.jpg
# done printing for  img_17.jpg
# done printing for  img_46813.jpg
# done printing for  img_14272.jpg
# done printing for  img_6560.jpg
# done printing for  img_28595.jpg
# done printing for  img_59004.jpg
# done printing for  img_15209.jpg
# done printing for  img_67659.jpg
# done printing for  img_13705.jpg
# done printing for  img_38475.jpg
# done printing for  img_95347.jpg
# done printing for  img_78366.jpg
# done printing for  img_58883.jpg
# done printing for  img_92708.jpg
# done printing for  img_66488.jpg
# done printing for  img_10889.jpg
# done printing for  img_9307.jpg
# done printing for  img_77492.jpg
# done printing for  img_98187.jpg
# done printing for  img_15394.jpg
# done printing for  img_11681.jpg
# done printing for  img_41113.jpg
# done printing for  img_43290.jpg
# done printing for  img_15061.jpg
# done printing for  img_92899.jpg
# done printing for  img_78689.jpg
# done printing for  img_39029.jpg
# done printing for  img_59686.jpg
# done printing for  img_77661.jpg
# done printing for  img_30247.jpg
# done printing for  img_100141.jpg
# done printing for  img_2721.jpg
# done printing for  img_100484.jpg
# done printing for  img_11435.jpg
# done printing for  img_12026.jpg
# done printing for  img_19945.jpg
# done printing for  img_74755.jpg
# done printing for  img_41851.jpg
# done printing for  img_31465.jpg
# done printing for  img_68342.jpg
# done printing for  img_39311.jpg
# done printing for  img_55585.jpg
# done printing for  img_91668.jpg
# done printing for  img_53346.jpg
# done printing for  img_99269.jpg
# done printing for  img_3997.jpg
# done printing for  img_101064.jpg
# done printing for  img_38440.jpg
# done printing for  img_8467.jpg
# done printing for  img_31933.jpg
# done printing for  img_100104.jpg
# done printing for  img_21933.jpg
# done printing for  img_79268.jpg
# done printing for  img_55738.jpg
# done printing for  img_29448.jpg
# done printing for  img_2673.jpg
# done printing for  img_67481.jpg
# done printing for  img_1656.jpg
# done printing for  img_23645.jpg
# done printing for  img_64996.jpg
# done printing for  img_15999.jpg
# done printing for  img_74722.jpg
# done printing for  img_23806.jpg
# done printing for  img_76301.jpg
# done printing for  img_52246.jpg
# done printing for  img_49436.jpg
# done printing for  img_62482.jpg
# done printing for  img_33692.jpg
# done printing for  img_95878.jpg
# done printing for  img_27027.jpg
# done printing for  img_49432.jpg
# done printing for  img_33846.jpg
# done printing for  img_82033.jpg
# done printing for  img_42333.jpg
# done printing for  img_6156.jpg
# done printing for  img_13407.jpg
# done printing for  img_69233.jpg
# done printing for  img_80401.jpg
# done printing for  img_17256.jpg
# done printing for  img_80880.jpg
# done printing for  img_94663.jpg
# done printing for  img_31324.jpg
# done printing for  img_53491.jpg
# done printing for  img_24812.jpg
# done printing for  img_4393.jpg
# done printing for  img_13581.jpg
# done printing for  img_67587.jpg
# done printing for  img_1188.jpg
# done printing for  img_50404.jpg
# done printing for  img_33921.jpg
# done printing for  img_75310.jpg
# done printing for  img_3355.jpg
# done printing for  img_39499.jpg
# done printing for  img_85863.jpg
# done printing for  img_96876.jpg
# done printing for  img_98283.jpg
# done printing for  img_58912.jpg
# done printing for  img_54799.jpg
# done printing for  img_24591.jpg
# done printing for  img_3334.jpg
# done printing for  img_19335.jpg
# done printing for  img_23179.jpg
# done printing for  img_12521.jpg
# done printing for  img_73774.jpg
# done printing for  img_77682.jpg
# done printing for  img_88966.jpg
# done printing for  img_73019.jpg
# done printing for  img_66626.jpg
# done printing for  img_69915.jpg
# done printing for  img_42405.jpg
# done printing for  img_94046.jpg
# done printing for  img_37403.jpg
# done printing for  img_93716.jpg
# done printing for  img_87065.jpg
# done printing for  img_76953.jpg
# done printing for  img_68018.jpg
# done printing for  img_95096.jpg
# done printing for  img_94021.jpg
# done printing for  img_53303.jpg
# done printing for  img_75918.jpg
# done printing for  img_73971.jpg
# done printing for  img_54295.jpg
# done printing for  img_15196.jpg
# done printing for  img_38895.jpg
# done printing for  img_47001.jpg
# done printing for  img_61256.jpg
# done printing for  img_94626.jpg
# done printing for  img_93176.jpg
# done printing for  img_46471.jpg
# done printing for  img_56086.jpg
# done printing for  img_100199.jpg
# done printing for  img_17279.jpg
# done printing for  img_68221.jpg
# done printing for  img_45030.jpg
# done printing for  img_28050.jpg
# done printing for  img_56864.jpg
# done printing for  img_59193.jpg
# done printing for  img_22731.jpg
# done printing for  img_46879.jpg
# done printing for  img_90043.jpg
# done printing for  img_37012.jpg
# done printing for  img_5566.jpg
# done printing for  img_63460.jpg
# done printing for  img_2237.jpg
# done printing for  img_83650.jpg
# done printing for  img_13005.jpg
# done printing for  img_56905.jpg
# done printing for  img_17040.jpg
# done printing for  img_52149.jpg
# done printing for  img_38661.jpg
# done printing for  img_52472.jpg
# done printing for  img_64501.jpg
# done printing for  img_5193.jpg
# done printing for  img_72692.jpg
# done printing for  img_59416.jpg
# done printing for  img_31482.jpg
# done printing for  img_27795.jpg
# done printing for  img_6022.jpg
# done printing for  img_76511.jpg
# done printing for  img_27317.jpg
# done printing for  img_69897.jpg
# done printing for  img_35704.jpg
# done printing for  img_34503.jpg
# done printing for  img_59980.jpg
# done printing for  img_36800.jpg
# done printing for  img_37085.jpg
# done printing for  img_28913.jpg
# done printing for  img_29243.jpg
# done printing for  img_42029.jpg
# done printing for  img_67122.jpg
# done printing for  img_28895.jpg
# done printing for  img_29999.jpg
# done printing for  img_26617.jpg
# done printing for  img_36014.jpg
# done printing for  img_18929.jpg
# done printing for  img_98272.jpg
# done printing for  img_92649.jpg
# done printing for  img_56730.jpg
# done printing for  img_53302.jpg
# done printing for  img_70703.jpg
# done printing for  img_62243.jpg
# done printing for  img_65800.jpg
# done printing for  img_68218.jpg
# done printing for  img_3410.jpg
# done printing for  img_45395.jpg
# done printing for  img_5323.jpg
# done printing for  img_100772.jpg
# done printing for  img_64862.jpg
# done printing for  img_26750.jpg
# done printing for  img_83206.jpg
# done printing for  img_102013.jpg
# done printing for  img_97752.jpg
# done printing for  img_47623.jpg
# done printing for  img_58604.jpg
# done printing for  img_38388.jpg
# done printing for  img_19965.jpg
# done printing for  img_13553.jpg
# done printing for  img_65408.jpg
# done printing for  img_11311.jpg
# done printing for  img_71186.jpg
# done printing for  img_10905.jpg
# done printing for  img_8621.jpg
# done printing for  img_53721.jpg
# done printing for  img_68177.jpg
# done printing for  img_37856.jpg
# done printing for  img_90574.jpg
# done printing for  img_7725.jpg
# done printing for  img_25111.jpg
# done printing for  img_63082.jpg
# done printing for  img_81001.jpg
# done printing for  img_22813.jpg
# done printing for  img_18063.jpg
# done printing for  img_38193.jpg
# done printing for  img_60612.jpg
# done printing for  img_68911.jpg
# done printing for  img_92215.jpg
# done printing for  img_59202.jpg
# done printing for  img_56993.jpg
# done printing for  img_48866.jpg
# done printing for  img_10886.jpg
# done printing for  img_42937.jpg
# done printing for  img_25541.jpg
# done printing for  img_15008.jpg
# done printing for  img_89143.jpg
# done printing for  img_80321.jpg
# done printing for  img_92191.jpg
# done printing for  img_84775.jpg
# done printing for  img_47357.jpg
# done printing for  img_18260.jpg
# done printing for  img_8173.jpg
# done printing for  img_73477.jpg
# done printing for  img_2947.jpg
# done printing for  img_90644.jpg
# done printing for  img_86662.jpg
# done printing for  img_34740.jpg
# done printing for  img_100234.jpg
# done printing for  img_13145.jpg
# done printing for  img_67862.jpg
# done printing for  img_99800.jpg
# done printing for  img_42231.jpg
# done printing for  img_44063.jpg
# done printing for  img_52361.jpg
# done printing for  img_47760.jpg
# done printing for  img_79382.jpg
# done printing for  img_59546.jpg
# done printing for  img_17735.jpg
# done printing for  img_71356.jpg
# done printing for  img_19906.jpg
# done printing for  img_93953.jpg
# done printing for  img_47740.jpg
# done printing for  img_33081.jpg
# done printing for  img_90066.jpg
# done printing for  img_63282.jpg
# done printing for  img_21105.jpg
# done printing for  img_64062.jpg
# done printing for  img_97348.jpg
# done printing for  img_19562.jpg
# done printing for  img_10315.jpg
# done printing for  img_69816.jpg
# done printing for  img_25507.jpg
# done printing for  img_47708.jpg
# done printing for  img_40446.jpg
# done printing for  img_101358.jpg
# done printing for  img_42364.jpg
# done printing for  img_191.jpg
# done printing for  img_12440.jpg
# done printing for  img_57767.jpg
# done printing for  img_30325.jpg
# done printing for  img_7705.jpg
# done printing for  img_8880.jpg
# done printing for  img_25542.jpg
# done printing for  img_64366.jpg
# done printing for  img_58900.jpg
# done printing for  img_16766.jpg
# done printing for  img_53732.jpg
# done printing for  img_32350.jpg
# done printing for  img_54116.jpg
# done printing for  img_77273.jpg
# done printing for  img_22024.jpg
# done printing for  img_88970.jpg
# done printing for  img_46781.jpg
# done printing for  img_18524.jpg
# done printing for  img_2156.jpg
# done printing for  img_21997.jpg
# done printing for  img_30.jpg
# done printing for  img_47124.jpg
# done printing for  img_98014.jpg
# done printing for  img_74818.jpg
# done printing for  img_41707.jpg
# done printing for  img_20279.jpg
# done printing for  img_88899.jpg
# done printing for  img_31298.jpg
# done printing for  img_15951.jpg
# done printing for  img_1771.jpg
# done printing for  img_67057.jpg
# done printing for  img_53345.jpg
# done printing for  img_20919.jpg
# done printing for  img_34801.jpg
# done printing for  img_38123.jpg
# done printing for  img_82533.jpg
# done printing for  img_2804.jpg
# done printing for  img_89611.jpg
# done printing for  img_21746.jpg
# done printing for  img_58851.jpg
# done printing for  img_4665.jpg
# done printing for  img_39196.jpg
# done printing for  img_78746.jpg
# done printing for  img_79509.jpg
# done printing for  img_37169.jpg
# done printing for  img_41837.jpg
# done printing for  img_18074.jpg
# done printing for  img_91563.jpg
# done printing for  img_86987.jpg
# done printing for  img_59690.jpg
# done printing for  img_70504.jpg
# done printing for  img_86631.jpg
# done printing for  img_15808.jpg
# done printing for  img_81888.jpg
# done printing for  img_25380.jpg
# done printing for  img_93393.jpg
# done printing for  img_1707.jpg
# done printing for  img_63923.jpg
# done printing for  img_96457.jpg
# done printing for  img_67123.jpg
# done printing for  img_1545.jpg
# done printing for  img_50472.jpg
# done printing for  img_62173.jpg
# done printing for  img_70661.jpg
# done printing for  img_71629.jpg
# done printing for  img_11884.jpg
# done printing for  img_78066.jpg
# done printing for  img_60081.jpg
# done printing for  img_50815.jpg
# done printing for  img_17883.jpg
# done printing for  img_56596.jpg
# done printing for  img_27737.jpg
# done printing for  img_28134.jpg
# done printing for  img_57068.jpg
# done printing for  img_31392.jpg
# done printing for  img_27981.jpg
# done printing for  img_56619.jpg
# done printing for  img_53420.jpg
# done printing for  img_15356.jpg
# done printing for  img_85383.jpg
# done printing for  img_33536.jpg
# done printing for  img_8492.jpg
# done printing for  img_92214.jpg
# done printing for  img_19791.jpg
# done printing for  img_100576.jpg
# done printing for  img_6477.jpg
# done printing for  img_82211.jpg
# done printing for  img_67917.jpg
# done printing for  img_99348.jpg
# done printing for  img_89019.jpg
# done printing for  img_40952.jpg
# done printing for  img_75803.jpg
# done printing for  img_7961.jpg
# done printing for  img_44668.jpg
# done printing for  img_25392.jpg
# done printing for  img_97416.jpg
# done printing for  img_35897.jpg
# done printing for  img_17199.jpg
# done printing for  img_84856.jpg
# done printing for  img_52729.jpg
# done printing for  img_91737.jpg
# done printing for  img_28992.jpg
# done printing for  img_71202.jpg
# done printing for  img_59420.jpg
# done printing for  img_53744.jpg
# done printing for  img_60396.jpg
# done printing for  img_91617.jpg
# done printing for  img_73628.jpg
# done printing for  img_44099.jpg
# done printing for  img_23918.jpg
# done printing for  img_80729.jpg
# done printing for  img_35906.jpg
# done printing for  img_8810.jpg
# done printing for  img_92264.jpg
# done printing for  img_26620.jpg
# done printing for  img_29855.jpg
# done printing for  img_6299.jpg
# done printing for  img_51596.jpg
# done printing for  img_9053.jpg
# done printing for  img_74817.jpg
# done printing for  img_68204.jpg
# done printing for  img_30848.jpg
# done printing for  img_37138.jpg
# done printing for  img_87659.jpg
# done printing for  img_30293.jpg
# done printing for  img_72738.jpg
# done printing for  img_53525.jpg
# done printing for  img_35247.jpg
# done printing for  img_65916.jpg
# done printing for  img_81990.jpg
# done printing for  img_50671.jpg
# done printing for  img_5925.jpg
# done printing for  img_88975.jpg
# done printing for  img_32292.jpg
# done printing for  img_80610.jpg
# done printing for  img_44664.jpg
# done printing for  img_30894.jpg
# done printing for  img_82976.jpg
# done printing for  img_88050.jpg
# done printing for  img_49298.jpg
# done printing for  img_94693.jpg
# done printing for  img_34258.jpg
# done printing for  img_37213.jpg
# done printing for  img_101890.jpg
# done printing for  img_80997.jpg
# done printing for  img_5166.jpg
# done printing for  img_59780.jpg
# done printing for  img_93612.jpg
# done printing for  img_20882.jpg
# done printing for  img_99026.jpg
# done printing for  img_89303.jpg
# done printing for  img_71994.jpg
# done printing for  img_6598.jpg
# done printing for  img_54539.jpg
# done printing for  img_30667.jpg
# done printing for  img_26882.jpg
# done printing for  img_12515.jpg
# done printing for  img_60910.jpg
# done printing for  img_43325.jpg
# done printing for  img_79383.jpg
# done printing for  img_90471.jpg
# done printing for  img_18120.jpg
# done printing for  img_30828.jpg
# done printing for  img_44219.jpg
# done printing for  img_57411.jpg
# done printing for  img_73312.jpg
# done printing for  img_18631.jpg
# done printing for  img_87087.jpg
# done printing for  img_99582.jpg
# done printing for  img_8149.jpg
# done printing for  img_54618.jpg
# done printing for  img_63370.jpg
# done printing for  img_77974.jpg
# done printing for  img_5445.jpg
# done printing for  img_99818.jpg
# done printing for  img_35857.jpg
# done printing for  img_907.jpg
# done printing for  img_33123.jpg
# done printing for  img_6034.jpg
# done printing for  img_100522.jpg
# done printing for  img_96326.jpg
# done printing for  img_57923.jpg
# done printing for  img_76417.jpg
# done printing for  img_52232.jpg
# done printing for  img_12847.jpg
# done printing for  img_76732.jpg
# done printing for  img_42549.jpg
# done printing for  img_68178.jpg
# done printing for  img_99533.jpg
# done printing for  img_63756.jpg
# done printing for  img_96488.jpg
# done printing for  img_7155.jpg
# done printing for  img_4857.jpg
# done printing for  img_22934.jpg
# done printing for  img_60372.jpg
# done printing for  img_75025.jpg
# done printing for  img_92768.jpg
# done printing for  img_32820.jpg
# done printing for  img_101595.jpg
# done printing for  img_34897.jpg
# done printing for  img_49554.jpg
# done printing for  img_43384.jpg
# done printing for  img_67755.jpg
# done printing for  img_13464.jpg
# done printing for  img_48818.jpg
# done printing for  img_14584.jpg
# done printing for  img_29894.jpg
# done printing for  img_13200.jpg
# done printing for  img_61997.jpg
# done printing for  img_25464.jpg
# done printing for  img_40598.jpg
# done printing for  img_98848.jpg
# done printing for  img_98732.jpg
# done printing for  img_6830.jpg
# done printing for  img_98759.jpg
# done printing for  img_82873.jpg
# done printing for  img_25326.jpg
# done printing for  img_10764.jpg
# done printing for  img_5561.jpg
# done printing for  img_34446.jpg
# done printing for  img_21934.jpg
# done printing for  img_68030.jpg
# done printing for  img_21377.jpg
# done printing for  img_52095.jpg
# done printing for  img_76291.jpg
# done printing for  img_84275.jpg
# done printing for  img_38767.jpg
# done printing for  img_58651.jpg
# done printing for  img_38397.jpg
# done printing for  img_89192.jpg
# done printing for  img_55991.jpg
# done printing for  img_23603.jpg
# done printing for  img_61714.jpg
# done printing for  img_84062.jpg
# done printing for  img_64310.jpg
# done printing for  img_25294.jpg
# done printing for  img_5405.jpg
# done printing for  img_16463.jpg
# done printing for  img_68947.jpg
# done printing for  img_19861.jpg
# done printing for  img_2455.jpg
# done printing for  img_2435.jpg
# done printing for  img_52315.jpg
# done printing for  img_7071.jpg
# done printing for  img_8373.jpg
# done printing for  img_479.jpg
# done printing for  img_51663.jpg
# done printing for  img_85774.jpg
# done printing for  img_14230.jpg
# done printing for  img_31119.jpg
# done printing for  img_39790.jpg
# done printing for  img_64870.jpg
# done printing for  img_78494.jpg
# done printing for  img_49304.jpg
# done printing for  img_30049.jpg
# done printing for  img_13346.jpg
# done printing for  img_28858.jpg
# done printing for  img_77426.jpg
# done printing for  img_25581.jpg
# done printing for  img_25264.jpg
# done printing for  img_9772.jpg
# done printing for  img_100929.jpg
# done printing for  img_89205.jpg
# done printing for  img_17455.jpg
# done printing for  img_45762.jpg
# done printing for  img_23601.jpg
# done printing for  img_14090.jpg
# done printing for  img_38370.jpg
# done printing for  img_32255.jpg
# done printing for  img_30940.jpg
# done printing for  img_45181.jpg
# done printing for  img_98268.jpg
# done printing for  img_70216.jpg
# done printing for  img_63100.jpg
# done printing for  img_39524.jpg
# done printing for  img_70972.jpg
# done printing for  img_15216.jpg
# done printing for  img_39333.jpg
# done printing for  img_89676.jpg
# done printing for  img_24456.jpg
# done printing for  img_36418.jpg
# done printing for  img_98821.jpg
# done printing for  img_38018.jpg
# done printing for  img_37599.jpg
# done printing for  img_1793.jpg
# done printing for  img_98018.jpg
# done printing for  img_90024.jpg
# done printing for  img_17667.jpg
# done printing for  img_46724.jpg
# done printing for  img_63805.jpg
# done printing for  img_78861.jpg
# done printing for  img_81298.jpg
# done printing for  img_30839.jpg
# done printing for  img_12965.jpg
# done printing for  img_93105.jpg
# done printing for  img_101556.jpg
# done printing for  img_87208.jpg
# done printing for  img_69979.jpg
# done printing for  img_9613.jpg
# done printing for  img_101538.jpg
# done printing for  img_43130.jpg
# done printing for  img_84498.jpg
# done printing for  img_1874.jpg
# done printing for  img_58775.jpg
# done printing for  img_9547.jpg
# done printing for  img_72430.jpg
# done printing for  img_32132.jpg
# done printing for  img_55426.jpg
# done printing for  img_94713.jpg
# done printing for  img_45806.jpg
# done printing for  img_14251.jpg
# done printing for  img_26193.jpg
# done printing for  img_84304.jpg
# done printing for  img_97856.jpg
# done printing for  img_73454.jpg
# done printing for  img_74340.jpg
# done printing for  img_20783.jpg
# done printing for  img_53514.jpg
# done printing for  img_8446.jpg
# done printing for  img_9753.jpg
# done printing for  img_36477.jpg
# done printing for  img_72629.jpg
# done printing for  img_59336.jpg
# done printing for  img_43881.jpg
# done printing for  img_14982.jpg
# done printing for  img_94147.jpg
# done printing for  img_96183.jpg
# done printing for  img_44654.jpg
# done printing for  img_35087.jpg
# done printing for  img_27733.jpg
# done printing for  img_82086.jpg
# done printing for  img_38255.jpg
# done printing for  img_71751.jpg
# done printing for  img_27953.jpg
# done printing for  img_52062.jpg
# done printing for  img_59543.jpg
# done printing for  img_8402.jpg
# done printing for  img_21696.jpg
# done printing for  img_57891.jpg
# done printing for  img_28454.jpg
# done printing for  img_27081.jpg
# done printing for  img_40627.jpg
# done printing for  img_54521.jpg
# done printing for  img_53374.jpg
# done printing for  img_6144.jpg
# done printing for  img_96053.jpg
# done printing for  img_96866.jpg
# done printing for  img_44959.jpg
# done printing for  img_41212.jpg
# done printing for  img_38314.jpg
# done printing for  img_56935.jpg
# done printing for  img_100387.jpg
# done printing for  img_19451.jpg
# done printing for  img_12130.jpg
# done printing for  img_77634.jpg
# done printing for  img_96177.jpg
# done printing for  img_9470.jpg
# done printing for  img_12940.jpg
# done printing for  img_3538.jpg
# done printing for  img_44265.jpg
# done printing for  img_28184.jpg
# done printing for  img_34323.jpg
# done printing for  img_33590.jpg
# done printing for  img_33137.jpg
# done printing for  img_21667.jpg
# done printing for  img_68436.jpg
# done printing for  img_100649.jpg
# done printing for  img_18885.jpg
# done printing for  img_65273.jpg
# done printing for  img_43548.jpg
# done printing for  img_77010.jpg
# done printing for  img_89003.jpg
# done printing for  img_21959.jpg
# done printing for  img_31941.jpg
# done printing for  img_67545.jpg
# done printing for  img_20442.jpg
# done printing for  img_74226.jpg
# done printing for  img_75080.jpg
# done printing for  img_52929.jpg
# done printing for  img_7707.jpg
# done printing for  img_61240.jpg
# done printing for  img_21602.jpg
# done printing for  img_45766.jpg
# done printing for  img_93962.jpg
# done printing for  img_71855.jpg
# done printing for  img_91987.jpg
# done printing for  img_79083.jpg
# done printing for  img_7001.jpg
# done printing for  img_58884.jpg
# done printing for  img_58532.jpg
# done printing for  img_27893.jpg
# done printing for  img_60745.jpg
# done printing for  img_73985.jpg
# done printing for  img_66061.jpg
# done printing for  img_57837.jpg
# done printing for  img_69673.jpg
# done printing for  img_11904.jpg
# done printing for  img_63354.jpg
# done printing for  img_13575.jpg
# done printing for  img_32515.jpg
# done printing for  img_14872.jpg
# done printing for  img_6980.jpg
# done printing for  img_32588.jpg
# done printing for  img_97078.jpg
# done printing for  img_14386.jpg
# done printing for  img_6260.jpg
# done printing for  img_2228.jpg
# done printing for  img_70463.jpg
# done printing for  img_23875.jpg
# done printing for  img_100080.jpg
# done printing for  img_33052.jpg
# done printing for  img_43295.jpg
# done printing for  img_724.jpg
# done printing for  img_41500.jpg
# done printing for  img_89849.jpg
# done printing for  img_14502.jpg
# done printing for  img_96286.jpg
# done printing for  img_4840.jpg
# done printing for  img_36974.jpg
# done printing for  img_75395.jpg
# done printing for  img_65575.jpg
# done printing for  img_72369.jpg
# done printing for  img_46596.jpg
# done printing for  img_44059.jpg
# done printing for  img_56953.jpg
# done printing for  img_85474.jpg
# done printing for  img_91385.jpg
# done printing for  img_19779.jpg
# done printing for  img_87672.jpg
# done printing for  img_69632.jpg
# done printing for  img_89878.jpg
# done printing for  img_4301.jpg
# done printing for  img_25069.jpg
# done printing for  img_89695.jpg
# done printing for  img_94258.jpg
# done printing for  img_91202.jpg
# done printing for  img_85426.jpg
# done printing for  img_26406.jpg
# done printing for  img_45621.jpg
# done printing for  img_32377.jpg
# done printing for  img_100555.jpg
# done printing for  img_76762.jpg
# done printing for  img_64529.jpg
# done printing for  img_62565.jpg
# done printing for  img_17284.jpg
# done printing for  img_32857.jpg
# done printing for  img_68017.jpg
# done printing for  img_80707.jpg
# done printing for  img_45714.jpg
# done printing for  img_8992.jpg
# done printing for  img_11856.jpg
# done printing for  img_3499.jpg
# done printing for  img_73746.jpg
# done printing for  img_6135.jpg
# done printing for  img_25976.jpg
# done printing for  img_71095.jpg
# done printing for  img_27659.jpg
# done printing for  img_48742.jpg
# done printing for  img_38016.jpg
# done printing for  img_38008.jpg
# done printing for  img_4772.jpg
# done printing for  img_56284.jpg
# done printing for  img_83160.jpg
# done printing for  img_83482.jpg
# done printing for  img_60107.jpg
# done printing for  img_96022.jpg
# done printing for  img_62675.jpg
# done printing for  img_53087.jpg
# done printing for  img_15150.jpg
# done printing for  img_13000.jpg
# done printing for  img_6953.jpg
# done printing for  img_58064.jpg
# done printing for  img_21603.jpg
# done printing for  img_101121.jpg
# done printing for  img_39615.jpg
# done printing for  img_36825.jpg
# done printing for  img_36389.jpg
# done printing for  img_96571.jpg
# done printing for  img_5621.jpg
# done printing for  img_42396.jpg
# done printing for  img_28618.jpg
# done printing for  img_80957.jpg
# done printing for  img_80558.jpg
# done printing for  img_42740.jpg
# done printing for  img_24669.jpg
# done printing for  img_76515.jpg
# done printing for  img_42423.jpg
# done printing for  img_62496.jpg
# done printing for  img_24466.jpg
# done printing for  img_67866.jpg
# done printing for  img_21826.jpg
# done printing for  img_98160.jpg
# done printing for  img_83574.jpg
# done printing for  img_46658.jpg
# done printing for  img_72419.jpg
# done printing for  img_11571.jpg
# done printing for  img_83333.jpg
# done printing for  img_83076.jpg
# done printing for  img_83271.jpg
# done printing for  img_17817.jpg
# done printing for  img_44677.jpg
# done printing for  img_55159.jpg
# done printing for  img_60001.jpg
# done printing for  img_68041.jpg
# done printing for  img_40473.jpg
# done printing for  img_62349.jpg
# done printing for  img_47788.jpg
# done printing for  img_96534.jpg
# done printing for  img_76737.jpg
# done printing for  img_3920.jpg
# done printing for  img_90554.jpg
# done printing for  img_87307.jpg
# done printing for  img_8150.jpg
# done printing for  img_19206.jpg
# done printing for  img_40322.jpg
# done printing for  img_90520.jpg
# done printing for  img_21801.jpg
# done printing for  img_98473.jpg
# done printing for  img_82719.jpg
# done printing for  img_12610.jpg
# done printing for  img_24901.jpg
# done printing for  img_64581.jpg
# done printing for  img_32921.jpg
# done printing for  img_9671.jpg
# done printing for  img_90235.jpg
# done printing for  img_36164.jpg
# done printing for  img_76598.jpg
# done printing for  img_11165.jpg
# done printing for  img_52759.jpg
# done printing for  img_85999.jpg
# done printing for  img_50836.jpg
# done printing for  img_7986.jpg
# done printing for  img_68501.jpg
# done printing for  img_5891.jpg
# done printing for  img_31045.jpg
# done printing for  img_47380.jpg
# done printing for  img_46815.jpg
# done printing for  img_53498.jpg
# done printing for  img_59481.jpg
# done printing for  img_6536.jpg
# done printing for  img_62799.jpg
# done printing for  img_72184.jpg
# done printing for  img_24633.jpg
# done printing for  img_40918.jpg
# done printing for  img_2842.jpg
# done printing for  img_25176.jpg
# done printing for  img_90566.jpg
# done printing for  img_59407.jpg
# done printing for  img_10069.jpg
# done printing for  img_78149.jpg
# done printing for  img_73735.jpg
# done printing for  img_73698.jpg
# done printing for  img_49285.jpg
# done printing for  img_72100.jpg
# done printing for  img_34271.jpg
# done printing for  img_63047.jpg
# done printing for  img_10344.jpg
# done printing for  img_99005.jpg
# done printing for  img_62131.jpg
# done printing for  img_11376.jpg
# done printing for  img_89046.jpg
# done printing for  img_84269.jpg
# done printing for  img_12125.jpg
# done printing for  img_52432.jpg
# done printing for  img_54073.jpg
# done printing for  img_55544.jpg
# done printing for  img_32746.jpg
# done printing for  img_82606.jpg
# done printing for  img_19663.jpg
# done printing for  img_82532.jpg
# done printing for  img_46639.jpg
# done printing for  img_9323.jpg
# done printing for  img_53637.jpg
# done printing for  img_93974.jpg
# done printing for  img_32378.jpg
# done printing for  img_100836.jpg
# done printing for  img_14302.jpg
# done printing for  img_19961.jpg
# done printing for  img_23363.jpg
# done printing for  img_67493.jpg
# done printing for  img_31754.jpg
# done printing for  img_97112.jpg
# done printing for  img_11538.jpg
# done printing for  img_2037.jpg
# done printing for  img_88166.jpg
# done printing for  img_53579.jpg
# done printing for  img_22607.jpg
# done printing for  img_21340.jpg
# done printing for  img_78567.jpg
# done printing for  img_64952.jpg
# done printing for  img_99178.jpg
# done printing for  img_55634.jpg
# done printing for  img_28910.jpg
# done printing for  img_85054.jpg
# done printing for  img_29691.jpg
# done printing for  img_63159.jpg
# done printing for  img_67128.jpg
# done printing for  img_53773.jpg
# done printing for  img_65040.jpg
# done printing for  img_48884.jpg
# done printing for  img_64838.jpg
# done printing for  img_100720.jpg
# done printing for  img_10448.jpg
# done printing for  img_17781.jpg
# done printing for  img_64590.jpg
# done printing for  img_18511.jpg
# done printing for  img_49254.jpg
# done printing for  img_79263.jpg
# done printing for  img_1460.jpg
# done printing for  img_43692.jpg
# done printing for  img_17499.jpg
# done printing for  img_31082.jpg
# done printing for  img_40398.jpg
# done printing for  img_31144.jpg
# done printing for  img_33463.jpg
# done printing for  img_48478.jpg
# done printing for  img_574.jpg
# done printing for  img_83605.jpg
# done printing for  img_36086.jpg
# done printing for  img_41010.jpg
# done printing for  img_8837.jpg
# done printing for  img_12201.jpg
# done printing for  img_76658.jpg
# done printing for  img_39831.jpg
# done printing for  img_62963.jpg
# done printing for  img_4220.jpg
# done printing for  img_6535.jpg
# done printing for  img_77949.jpg
# done printing for  img_31308.jpg
# done printing for  img_46466.jpg
# done printing for  img_22741.jpg
# done printing for  img_81570.jpg
# done printing for  img_70075.jpg
# done printing for  img_48819.jpg
# done printing for  img_25882.jpg
# done printing for  img_39353.jpg
# done printing for  img_62735.jpg
# done printing for  img_89659.jpg
# done printing for  img_31748.jpg
# done printing for  img_7664.jpg
# done printing for  img_30635.jpg
# done printing for  img_20586.jpg
# done printing for  img_101322.jpg
# done printing for  img_8713.jpg
# done printing for  img_63173.jpg
# done printing for  img_35644.jpg
# done printing for  img_66365.jpg
# done printing for  img_75268.jpg
# done printing for  img_64583.jpg
# done printing for  img_57220.jpg
# done printing for  img_54962.jpg
# done printing for  img_15548.jpg
# done printing for  img_91937.jpg
# done printing for  img_91050.jpg
# done printing for  img_52918.jpg
# done printing for  img_67777.jpg
# done printing for  img_35537.jpg
# done printing for  img_17655.jpg
# done printing for  img_45166.jpg
# done printing for  img_19980.jpg
# done printing for  img_53341.jpg
# done printing for  img_83379.jpg
# done printing for  img_10899.jpg
# done printing for  img_20572.jpg
# done printing for  img_71847.jpg
# done printing for  img_64173.jpg
# done printing for  img_20047.jpg
# done printing for  img_23146.jpg
# done printing for  img_72843.jpg
# done printing for  img_27166.jpg
# done printing for  img_78393.jpg
# done printing for  img_88137.jpg
# done printing for  img_60736.jpg
# done printing for  img_64615.jpg
# done printing for  img_88384.jpg
# done printing for  img_58211.jpg
# done printing for  img_9931.jpg
# done printing for  img_7023.jpg
# done printing for  img_76187.jpg
# done printing for  img_54009.jpg
# done printing for  img_41102.jpg
# done printing for  img_37601.jpg
# done printing for  img_51085.jpg
# done printing for  img_59595.jpg
# done printing for  img_72707.jpg
# done printing for  img_22767.jpg
# done printing for  img_55075.jpg
# done printing for  img_77281.jpg
# done printing for  img_6978.jpg
# done printing for  img_28632.jpg
# done printing for  img_76332.jpg
# done printing for  img_54384.jpg
# done printing for  img_36223.jpg
# done printing for  img_29391.jpg
# done printing for  img_74622.jpg
# done printing for  img_80331.jpg
# done printing for  img_13526.jpg
# done printing for  img_93284.jpg
# done printing for  img_28820.jpg
# done printing for  img_18861.jpg
# done printing for  img_50386.jpg
# done printing for  img_71722.jpg
# done printing for  img_20567.jpg
# done printing for  img_71491.jpg
# done printing for  img_90165.jpg
# done printing for  img_5988.jpg
# done printing for  img_44475.jpg
# done printing for  img_73169.jpg
# done printing for  img_90411.jpg
# done printing for  img_100097.jpg
# done printing for  img_50616.jpg
# done printing for  img_31147.jpg
# done printing for  img_38394.jpg
# done printing for  img_33232.jpg
# done printing for  img_93367.jpg
# done printing for  img_9899.jpg
# done printing for  img_56781.jpg
# done printing for  img_86006.jpg
# done printing for  img_86695.jpg
# done printing for  img_16015.jpg
# done printing for  img_4982.jpg
# done printing for  img_55705.jpg
# done printing for  img_66160.jpg
# done printing for  img_5397.jpg
# done printing for  img_80715.jpg
# done printing for  img_12278.jpg
# done printing for  img_91669.jpg
# done printing for  img_55635.jpg
# done printing for  img_35909.jpg
# done printing for  img_69848.jpg
# done printing for  img_17926.jpg
# done printing for  img_18979.jpg
# done printing for  img_54790.jpg
# done printing for  img_74983.jpg
# done printing for  img_98231.jpg
# done printing for  img_73433.jpg
# done printing for  img_3247.jpg
# done printing for  img_24617.jpg
# done printing for  img_78651.jpg
# done printing for  img_69847.jpg
# done printing for  img_91502.jpg
# done printing for  img_47392.jpg
# done printing for  img_4231.jpg
# done printing for  img_91904.jpg
# done printing for  img_63974.jpg
# done printing for  img_33098.jpg
# done printing for  img_82805.jpg
# done printing for  img_64127.jpg
# done printing for  img_11383.jpg
# done printing for  img_30718.jpg
# done printing for  img_95687.jpg
# done printing for  img_66391.jpg
# done printing for  img_63499.jpg
# done printing for  img_55508.jpg
# done printing for  img_18092.jpg
# done printing for  img_87566.jpg
# done printing for  img_79777.jpg
# done printing for  img_2740.jpg
# done printing for  img_556.jpg
# done printing for  img_66630.jpg
# done printing for  img_75806.jpg
# done printing for  img_39630.jpg
# done printing for  img_69818.jpg
# done printing for  img_18348.jpg
# done printing for  img_75469.jpg
# done printing for  img_6203.jpg
# done printing for  img_8428.jpg
# done printing for  img_45183.jpg
# done printing for  img_45661.jpg
# done printing for  img_46183.jpg
# done printing for  img_67672.jpg
# done printing for  img_8170.jpg
# done printing for  img_38523.jpg
# done printing for  img_46084.jpg
# done printing for  img_62693.jpg
# done printing for  img_85310.jpg
# done printing for  img_20930.jpg
# done printing for  img_60792.jpg
# done printing for  img_68610.jpg
# done printing for  img_56885.jpg
# done printing for  img_91168.jpg
# done printing for  img_17206.jpg
# done printing for  img_34469.jpg
# done printing for  img_50260.jpg
# done printing for  img_1550.jpg
# done printing for  img_6800.jpg
# done printing for  img_97241.jpg
# done printing for  img_40738.jpg
# done printing for  img_92830.jpg
# done printing for  img_28659.jpg
# done printing for  img_42443.jpg
# done printing for  img_16695.jpg
# done printing for  img_11110.jpg
# done printing for  img_8760.jpg
# done printing for  img_77418.jpg
# done printing for  img_76797.jpg
# done printing for  img_32441.jpg
# done printing for  img_40767.jpg
# done printing for  img_6897.jpg
# done printing for  img_82590.jpg
# done printing for  img_96682.jpg
# done printing for  img_13457.jpg
# done printing for  img_58251.jpg
# done printing for  img_51609.jpg
# done printing for  img_71828.jpg
# done printing for  img_48685.jpg
# done printing for  img_61747.jpg
# done printing for  img_11934.jpg
# done printing for  img_38443.jpg
# done printing for  img_70858.jpg
# done printing for  img_51924.jpg
# done printing for  img_53999.jpg
# done printing for  img_11102.jpg
# done printing for  img_45059.jpg
# done printing for  img_93007.jpg
# done printing for  img_80188.jpg
# done printing for  img_29584.jpg
# done printing for  img_85919.jpg
# done printing for  img_522.jpg
# done printing for  img_34050.jpg
# done printing for  img_74486.jpg
# done printing for  img_59736.jpg
# done printing for  img_5622.jpg
# done printing for  img_70098.jpg
# done printing for  img_43565.jpg
# done printing for  img_90341.jpg
# done printing for  img_39011.jpg
# done printing for  img_44679.jpg
# done printing for  img_100462.jpg
# done printing for  img_83573.jpg
# done printing for  img_54897.jpg
# done printing for  img_23879.jpg
# done printing for  img_14137.jpg
# done printing for  img_61576.jpg
# done printing for  img_85137.jpg
# done printing for  img_39033.jpg
# done printing for  img_34872.jpg
# done printing for  img_44897.jpg
# done printing for  img_55181.jpg
# done printing for  img_21439.jpg
# done printing for  img_98049.jpg
# done printing for  img_12386.jpg
# done printing for  img_91398.jpg
# done printing for  img_48564.jpg
# done printing for  img_77734.jpg
# done printing for  img_13250.jpg
# done printing for  img_82534.jpg
# done printing for  img_76553.jpg
# done printing for  img_33105.jpg
# done printing for  img_26612.jpg
# done printing for  img_29460.jpg
# done printing for  img_7663.jpg
# done printing for  img_84255.jpg
# done printing for  img_72501.jpg
# done printing for  img_50832.jpg
# done printing for  img_43072.jpg
# done printing for  img_97782.jpg
# done printing for  img_91558.jpg
# done printing for  img_33720.jpg
# done printing for  img_30074.jpg
# done printing for  img_95150.jpg
# done printing for  img_88830.jpg
# done printing for  img_18555.jpg
# done printing for  img_37252.jpg
# done printing for  img_13882.jpg
# done printing for  img_49881.jpg
# done printing for  img_92832.jpg
# done printing for  img_76377.jpg
# done printing for  img_16420.jpg
# done printing for  img_7150.jpg
# done printing for  img_101546.jpg
# done printing for  img_2506.jpg
# done printing for  img_29214.jpg
# done printing for  img_76151.jpg
# done printing for  img_18103.jpg
# done printing for  img_41211.jpg
# done printing for  img_58153.jpg
# done printing for  img_87953.jpg
# done printing for  img_78599.jpg
# done printing for  img_49666.jpg
# done printing for  img_18593.jpg
# done printing for  img_47376.jpg
# done printing for  img_9801.jpg
# done printing for  img_51021.jpg
# done printing for  img_49972.jpg
# done printing for  img_16922.jpg
# done printing for  img_19288.jpg
# done printing for  img_31471.jpg
# done printing for  img_17304.jpg
# done printing for  img_94251.jpg
# done printing for  img_46744.jpg
# done printing for  img_27565.jpg
# done printing for  img_39440.jpg
# done printing for  img_87696.jpg
# done printing for  img_27581.jpg
# done printing for  img_87114.jpg
# done printing for  img_19643.jpg
# done printing for  img_23502.jpg
# done printing for  img_95157.jpg
# done printing for  img_96414.jpg
# done printing for  img_25328.jpg
# done printing for  img_21130.jpg
# done printing for  img_26782.jpg
# done printing for  img_45669.jpg
# done printing for  img_52116.jpg
# done printing for  img_27956.jpg
# done printing for  img_73493.jpg
# done printing for  img_16303.jpg
# done printing for  img_65022.jpg
# done printing for  img_27879.jpg
# done printing for  img_18787.jpg
# done printing for  img_32835.jpg
# done printing for  img_63538.jpg
# done printing for  img_54654.jpg
# done printing for  img_91589.jpg
# done printing for  img_82281.jpg
# done printing for  img_14747.jpg
# done printing for  img_36417.jpg
# done printing for  img_41672.jpg
# done printing for  img_30364.jpg
# done printing for  img_47242.jpg
# done printing for  img_5061.jpg
# done printing for  img_15978.jpg
# done printing for  img_85954.jpg
# done printing for  img_68289.jpg
# done printing for  img_82284.jpg
# done printing for  img_8103.jpg
# done printing for  img_34831.jpg
# done printing for  img_26351.jpg
# done printing for  img_8869.jpg
# done printing for  img_90361.jpg
# done printing for  img_5182.jpg
# done printing for  img_54909.jpg
# done printing for  img_78350.jpg
# done printing for  img_74682.jpg
# done printing for  img_33973.jpg
# done printing for  img_16543.jpg
# done printing for  img_11348.jpg
# done printing for  img_3441.jpg
# done printing for  img_1426.jpg
# done printing for  img_62232.jpg
# done printing for  img_4800.jpg
# done printing for  img_42307.jpg
# done printing for  img_39520.jpg
# done printing for  img_32071.jpg
# done printing for  img_65372.jpg
# done printing for  img_14221.jpg
# done printing for  img_74637.jpg
# done printing for  img_73048.jpg
# done printing for  img_17223.jpg
# done printing for  img_88030.jpg
# done printing for  img_39663.jpg
# done printing for  img_9898.jpg
# done printing for  img_76520.jpg
# done printing for  img_90455.jpg
# done printing for  img_84626.jpg
# done printing for  img_10088.jpg
# done printing for  img_62387.jpg
# done printing for  img_29579.jpg
# done printing for  img_8277.jpg
# done printing for  img_78356.jpg
# done printing for  img_44592.jpg
# done printing for  img_27874.jpg
# done printing for  img_89411.jpg
# done printing for  img_37933.jpg
# done printing for  img_59535.jpg
# done printing for  img_45591.jpg
# done printing for  img_88302.jpg
# done printing for  img_40736.jpg
# done printing for  img_3676.jpg
# done printing for  img_76241.jpg
# done printing for  img_6761.jpg
# done printing for  img_1985.jpg
# done printing for  img_32833.jpg
# done printing for  img_23163.jpg
# done printing for  img_101724.jpg
# done printing for  img_49267.jpg
# done printing for  img_41945.jpg
# done printing for  img_23377.jpg
# done printing for  img_6449.jpg
# done printing for  img_36554.jpg
# done printing for  img_94654.jpg
# done printing for  img_22539.jpg
# done printing for  img_56378.jpg
# done printing for  img_76056.jpg
# done printing for  img_17646.jpg
# done printing for  img_93599.jpg
# done printing for  img_61455.jpg
# done printing for  img_24810.jpg
# done printing for  img_98048.jpg
# done printing for  img_57695.jpg
# done printing for  img_1102.jpg
# done printing for  img_73315.jpg
# done printing for  img_66383.jpg
# done printing for  img_72266.jpg
# done printing for  img_8514.jpg
# done printing for  img_16511.jpg
# done printing for  img_4021.jpg
# done printing for  img_85788.jpg
# done printing for  img_46201.jpg
# done printing for  img_100288.jpg
# done printing for  img_25605.jpg
# done printing for  img_90715.jpg
# done printing for  img_10421.jpg
# done printing for  img_2083.jpg
# done printing for  img_97648.jpg
# done printing for  img_86356.jpg
# done printing for  img_67130.jpg
# done printing for  img_13832.jpg
# done printing for  img_77869.jpg
# done printing for  img_52390.jpg
# done printing for  img_76097.jpg
# done printing for  img_73425.jpg
# done printing for  img_84741.jpg
# done printing for  img_33544.jpg
# done printing for  img_9340.jpg
# done printing for  img_6248.jpg
# done printing for  img_22065.jpg
# done printing for  img_36627.jpg
# done printing for  img_88812.jpg
# done printing for  img_79834.jpg
# done printing for  img_26982.jpg
# done printing for  img_63123.jpg
# done printing for  img_55099.jpg
# done printing for  img_8955.jpg
# done printing for  img_68234.jpg
# done printing for  img_60580.jpg
# ...
# done printing for  img_32495.jpg
# done printing for  img_43476.jpg
# done printing for  img_27265.jpg
# done printing for  img_98921.jpg
# done printing for  img_15322.jpg
# done printing for  img_63071.jpg
# done printing for  img_34405.jpg
# done printing for  img_8732.jpg
# done printing for  img_65878.jpg
# done printing for  img_95539.jpg
# done printing for  img_30108.jpg
# done printing for  img_88831.jpg
# done printing for  img_99933.jpg
# done printing for  img_55735.jpg
# done printing for  img_29353.jpg
# done printing for  img_565.jpg
# done printing for  img_58389.jpg
# done printing for  img_56852.jpg
# done printing for  img_43866.jpg
# done printing for  img_46326.jpg
# done printing for  img_32530.jpg
# done printing for  img_16656.jpg
# done printing for  img_19886.jpg
# done printing for  img_23544.jpg
# done printing for  img_8148.jpg
# done printing for  img_12065.jpg
# done printing for  img_58992.jpg
# done printing for  img_95425.jpg
# done printing for  img_97345.jpg
# done printing for  img_30016.jpg
# done printing for  img_10981.jpg
# done printing for  img_61860.jpg
# done printing for  img_77031.jpg
# done printing for  img_36146.jpg
# done printing for  img_31864.jpg
# done printing for  img_68089.jpg
# done printing for  img_77077.jpg
# done printing for  img_72688.jpg
# done printing for  img_49560.jpg
# done printing for  img_6120.jpg
# done printing for  img_30962.jpg
# done printing for  img_2204.jpg
# done printing for  img_83546.jpg
# done printing for  img_34617.jpg
# done printing for  img_45221.jpg
# done printing for  img_100424.jpg
# done printing for  img_63509.jpg
# done printing for  img_51932.jpg
# done printing for  img_86331.jpg
# done printing for  img_46628.jpg
# done printing for  img_7529.jpg
# done printing for  img_59185.jpg
# done printing for  img_60314.jpg
# done printing for  img_75761.jpg
# done printing for  img_28809.jpg
# done printing for  img_56165.jpg
# done printing for  img_49838.jpg
# done printing for  img_67158.jpg
# done printing for  img_28922.jpg
# done printing for  img_78124.jpg
# done printing for  img_88679.jpg
# done printing for  img_69660.jpg
# done printing for  img_73357.jpg
# done printing for  img_65831.jpg
# done printing for  img_32329.jpg
# done printing for  img_40512.jpg
# done printing for  img_3495.jpg
# done printing for  img_79531.jpg
# done printing for  img_92268.jpg
# done printing for  img_47737.jpg
# done printing for  img_92895.jpg
# done printing for  img_42237.jpg
# done printing for  img_94811.jpg
# done printing for  img_46941.jpg
# done printing for  img_97199.jpg
# done printing for  img_54028.jpg
# done printing for  img_72236.jpg
# done printing for  img_22549.jpg
# done printing for  img_38803.jpg
# done printing for  img_67965.jpg
# done printing for  img_58159.jpg
# done printing for  img_26106.jpg
# done printing for  img_77827.jpg
# done printing for  img_72108.jpg
# done printing for  img_47853.jpg
# done printing for  img_7206.jpg
# done printing for  img_21368.jpg
# done printing for  img_3588.jpg
# done printing for  img_84580.jpg
# done printing for  img_34887.jpg
# done printing for  img_18637.jpg
# done printing for  img_46974.jpg
# done printing for  img_80639.jpg
# done printing for  img_33186.jpg
# done printing for  img_21202.jpg
# done printing for  img_4898.jpg
# done printing for  img_22275.jpg
# done printing for  img_93854.jpg
# done printing for  img_47152.jpg
# done printing for  img_96797.jpg
# done printing for  img_28035.jpg
# done printing for  img_91572.jpg
# done printing for  img_94885.jpg
# done printing for  img_38159.jpg
# done printing for  img_82206.jpg
# done printing for  img_16419.jpg
# done printing for  img_33749.jpg
# done printing for  img_79971.jpg
# done printing for  img_72511.jpg
# done printing for  img_56840.jpg
# done printing for  img_21115.jpg
# done printing for  img_51382.jpg
# done printing for  img_19444.jpg
# done printing for  img_72026.jpg
# done printing for  img_45108.jpg
# done printing for  img_86100.jpg
# done printing for  img_44313.jpg
# done printing for  img_92886.jpg
# done printing for  img_33817.jpg
# done printing for  img_70806.jpg
# done printing for  img_12884.jpg
# done printing for  img_74830.jpg
# done printing for  img_19148.jpg
# done printing for  img_72970.jpg
# done printing for  img_28776.jpg
# done printing for  img_63099.jpg
# done printing for  img_59603.jpg
# done printing for  img_34493.jpg
# done printing for  img_68139.jpg
# done printing for  img_36790.jpg
# done printing for  img_46289.jpg
# done printing for  img_76206.jpg
# done printing for  img_37574.jpg
# done printing for  img_77649.jpg
# done printing for  img_18616.jpg
# done printing for  img_70192.jpg
# done printing for  img_78809.jpg
# done printing for  img_95926.jpg
# done printing for  img_49677.jpg
# done printing for  img_60460.jpg
# done printing for  img_7029.jpg
# done printing for  img_52397.jpg
# done printing for  img_41418.jpg
# done printing for  img_71121.jpg
# done printing for  img_59362.jpg
# done printing for  img_42239.jpg
# done printing for  img_69661.jpg
# done printing for  img_39536.jpg
# done printing for  img_20751.jpg
# done printing for  img_36177.jpg
# done printing for  img_19268.jpg
# done printing for  img_50165.jpg
# done printing for  img_73921.jpg
# done printing for  img_49802.jpg
# done printing for  img_2221.jpg
# done printing for  img_67690.jpg
# done printing for  img_68051.jpg
# done printing for  img_34081.jpg
# done printing for  img_3487.jpg
# done printing for  img_32635.jpg
# done printing for  img_16152.jpg
# done printing for  img_39532.jpg
# done printing for  img_20932.jpg
# done printing for  img_67904.jpg
# done printing for  img_520.jpg
# done printing for  img_96756.jpg
# done printing for  img_33833.jpg
# done printing for  img_13434.jpg
# done printing for  img_58415.jpg
# done printing for  img_84902.jpg
# done printing for  img_32228.jpg
# done printing for  img_37928.jpg
# done printing for  img_78262.jpg
# done printing for  img_47245.jpg
# done printing for  img_90238.jpg
# done printing for  img_81886.jpg
# done printing for  img_86036.jpg
# done printing for  img_83052.jpg
# done printing for  img_73569.jpg
# done printing for  img_54609.jpg
# done printing for  img_76262.jpg
# done printing for  img_55821.jpg
# done printing for  img_33485.jpg
# done printing for  img_38839.jpg
# done printing for  img_79772.jpg
# done printing for  img_79403.jpg
# done printing for  img_55887.jpg
# done printing for  img_30052.jpg
# done printing for  img_62077.jpg
# done printing for  img_80718.jpg
# done printing for  img_54236.jpg
# done printing for  img_21478.jpg
# done printing for  img_67392.jpg
# done printing for  img_2990.jpg
# done printing for  img_5123.jpg
# done printing for  img_82222.jpg
# done printing for  img_11062.jpg
# done printing for  img_55362.jpg
# done printing for  img_78416.jpg
# done printing for  img_76766.jpg
# done printing for  img_49999.jpg
# done printing for  img_42243.jpg
# done printing for  img_66744.jpg
# done printing for  img_42207.jpg
# done printing for  img_68742.jpg
# done printing for  img_65369.jpg
# done printing for  img_11664.jpg
# done printing for  img_98033.jpg
# done printing for  img_99868.jpg
# done printing for  img_67572.jpg
# done printing for  img_88477.jpg
# done printing for  img_10035.jpg
# done printing for  img_22942.jpg
# done printing for  img_17367.jpg
# done printing for  img_37006.jpg
# done printing for  img_4774.jpg
# done printing for  img_95809.jpg
# done printing for  img_16905.jpg
# done printing for  img_74149.jpg
# done printing for  img_5812.jpg
# done printing for  img_43214.jpg
# done printing for  img_59806.jpg
# done printing for  img_15606.jpg
# done printing for  img_36076.jpg
# done printing for  img_47141.jpg
# done printing for  img_95282.jpg
# done printing for  img_12461.jpg
# done printing for  img_21910.jpg
# done printing for  img_87997.jpg
# done printing for  img_32070.jpg
# done printing for  img_29567.jpg
# done printing for  img_52265.jpg
# done printing for  img_74925.jpg
# done printing for  img_2390.jpg
# done printing for  img_67770.jpg
# done printing for  img_96163.jpg
# done printing for  img_56460.jpg
# done printing for  img_66978.jpg
# done printing for  img_18995.jpg
# done printing for  img_81119.jpg
# done printing for  img_27555.jpg
# done printing for  img_23398.jpg
# done printing for  img_51992.jpg
# done printing for  img_1553.jpg
# done printing for  img_66865.jpg
# done printing for  img_51700.jpg
# done printing for  img_59573.jpg
# done printing for  img_77656.jpg
# done printing for  img_7706.jpg
# done printing for  img_15532.jpg
# done printing for  img_69969.jpg
# done printing for  img_54506.jpg
# done printing for  img_83350.jpg
# done printing for  img_73760.jpg
# done printing for  img_76287.jpg
# done printing for  img_99724.jpg
# done printing for  img_15531.jpg
# done printing for  img_56461.jpg
# done printing for  img_83198.jpg
# done printing for  img_88991.jpg
# done printing for  img_17041.jpg
# done printing for  img_81652.jpg
# done printing for  img_80136.jpg
# done printing for  img_67492.jpg
# done printing for  img_44103.jpg
# done printing for  img_77381.jpg
# done printing for  img_560.jpg
# done printing for  img_4717.jpg
# done printing for  img_70973.jpg
# done printing for  img_91036.jpg
# done printing for  img_78626.jpg
# done printing for  img_90304.jpg
# done printing for  img_51250.jpg
# done printing for  img_35609.jpg
# done printing for  img_23078.jpg
# done printing for  img_24399.jpg
# done printing for  img_68627.jpg
# done printing for  img_71386.jpg
# done printing for  img_43972.jpg
# done printing for  img_26008.jpg
# done printing for  img_90718.jpg
# done printing for  img_69670.jpg
# done printing for  img_99338.jpg
# done printing for  img_11756.jpg
# done printing for  img_88404.jpg
# done printing for  img_89125.jpg
# done printing for  img_96048.jpg
# done printing for  img_3992.jpg
# done printing for  img_56759.jpg
# done printing for  img_84232.jpg
# done printing for  img_99176.jpg
# done printing for  img_88029.jpg
# done printing for  img_76305.jpg
# done printing for  img_84795.jpg
# done printing for  img_8029.jpg
# done printing for  img_25531.jpg
# done printing for  img_19361.jpg
# done printing for  img_41910.jpg
# done printing for  img_77131.jpg
# done printing for  img_90352.jpg
# done printing for  img_497.jpg
# done printing for  img_58232.jpg
# done printing for  img_44685.jpg
# done printing for  img_15393.jpg
# done printing for  img_75109.jpg
# done printing for  img_59060.jpg
# done printing for  img_23610.jpg
# done printing for  img_73074.jpg
# done printing for  img_67389.jpg
# done printing for  img_37822.jpg
# done printing for  img_41829.jpg
# done printing for  img_7921.jpg
# done printing for  img_56261.jpg
# done printing for  img_1151.jpg
# done printing for  img_95167.jpg
# done printing for  img_33864.jpg
# done printing for  img_52321.jpg
# done printing for  img_13361.jpg
# done printing for  img_25707.jpg
# done printing for  img_42422.jpg
# done printing for  img_66993.jpg
# done printing for  img_51263.jpg
# done printing for  img_13984.jpg
# done printing for  img_54865.jpg
# done printing for  img_88241.jpg
# done printing for  img_52874.jpg
# done printing for  img_55628.jpg
# done printing for  img_10043.jpg
# done printing for  img_49319.jpg
# done printing for  img_81908.jpg
# done printing for  img_97927.jpg
# done printing for  img_64362.jpg
# done printing for  img_92778.jpg
# done printing for  img_36368.jpg
# done printing for  img_93563.jpg
# done printing for  img_4731.jpg
# done printing for  img_90682.jpg
# done printing for  img_37943.jpg
# done printing for  img_27708.jpg
# done printing for  img_42406.jpg
# done printing for  img_65401.jpg
# done printing for  img_97003.jpg
# done printing for  img_79205.jpg
# done printing for  img_75416.jpg
# done printing for  img_54189.jpg
# done printing for  img_77643.jpg
# done printing for  img_18646.jpg
# done printing for  img_20081.jpg
# done printing for  img_72158.jpg
# done printing for  img_99787.jpg
# done printing for  img_47807.jpg
# done printing for  img_5982.jpg
# done printing for  img_64926.jpg
# done printing for  img_64211.jpg
# done printing for  img_71157.jpg
# done printing for  img_25056.jpg
# done printing for  img_92306.jpg
# done printing for  img_56279.jpg
# done printing for  img_43241.jpg
# done printing for  img_96231.jpg
# done printing for  img_66577.jpg
# done printing for  img_90052.jpg
# done printing for  img_78119.jpg
# done printing for  img_848.jpg
# done printing for  img_37193.jpg
# done printing for  img_18332.jpg
# done printing for  img_49709.jpg
# done printing for  img_60442.jpg
# done printing for  img_1397.jpg
# done printing for  img_98382.jpg
# done printing for  img_95448.jpg
# done printing for  img_77389.jpg
# done printing for  img_36376.jpg
# done printing for  img_44727.jpg
# done printing for  img_93113.jpg
# done printing for  img_3748.jpg
# done printing for  img_1626.jpg
# done printing for  img_53237.jpg
# done printing for  img_41443.jpg
# done printing for  img_83626.jpg
# done printing for  img_75506.jpg
# done printing for  img_50300.jpg
# done printing for  img_40450.jpg
# done printing for  img_2867.jpg
# done printing for  img_21875.jpg
# done printing for  img_5418.jpg
# done printing for  img_20342.jpg
# done printing for  img_58102.jpg
# done printing for  img_16946.jpg
# done printing for  img_76396.jpg
# done printing for  img_36953.jpg
# done printing for  img_86456.jpg
# done printing for  img_2629.jpg
# done printing for  img_18642.jpg
# done printing for  img_37850.jpg
# done printing for  img_49071.jpg
# done printing for  img_17727.jpg
# done printing for  img_46009.jpg
# done printing for  img_10041.jpg
# done printing for  img_65870.jpg
# done printing for  img_41235.jpg
# done printing for  img_76563.jpg
# done printing for  img_91530.jpg
# done printing for  img_62381.jpg
# done printing for  img_56915.jpg
# done printing for  img_96787.jpg
# done printing for  img_83462.jpg
# done printing for  img_100068.jpg
# done printing for  img_13670.jpg
# done printing for  img_4097.jpg
# done printing for  img_77103.jpg
# done printing for  img_28691.jpg
# done printing for  img_15952.jpg
# done printing for  img_5494.jpg
# done printing for  img_100891.jpg
# done printing for  img_17739.jpg
# done printing for  img_20707.jpg
# done printing for  img_98260.jpg
# done printing for  img_50872.jpg
# done printing for  img_45658.jpg
# done printing for  img_33124.jpg
# done printing for  img_59074.jpg
# done printing for  img_7003.jpg
# done printing for  img_67249.jpg
# done printing for  img_38611.jpg
# done printing for  img_58504.jpg
# done printing for  img_57396.jpg
# done printing for  img_78132.jpg
# done printing for  img_97798.jpg
# done printing for  img_27211.jpg
# done printing for  img_22672.jpg
# done printing for  img_25204.jpg
# done printing for  img_33101.jpg
# done printing for  img_87312.jpg
# done printing for  img_14179.jpg
# done printing for  img_16591.jpg
# done printing for  img_70140.jpg
# done printing for  img_25918.jpg
# done printing for  img_98497.jpg
# done printing for  img_3341.jpg
# done printing for  img_7614.jpg
# done printing for  img_27600.jpg
# done printing for  img_87871.jpg
# done printing for  img_56541.jpg
# done printing for  img_60224.jpg
# done printing for  img_63838.jpg
# done printing for  img_85559.jpg
# done printing for  img_11262.jpg
# done printing for  img_5976.jpg
# done printing for  img_29373.jpg
# done printing for  img_52543.jpg
# done printing for  img_81877.jpg
# done printing for  img_71989.jpg
# done printing for  img_43300.jpg
# done printing for  img_73604.jpg
# done printing for  img_60682.jpg
# done printing for  img_74214.jpg
# done printing for  img_21206.jpg
# done printing for  img_29992.jpg
# done printing for  img_54986.jpg
# done printing for  img_66706.jpg
# done printing for  img_46938.jpg
# done printing for  img_79581.jpg
# done printing for  img_290.jpg
# done printing for  img_25985.jpg
# done printing for  img_30396.jpg
# done printing for  img_60782.jpg
# done printing for  img_40002.jpg
# done printing for  img_93276.jpg
# done printing for  img_37750.jpg
# done printing for  img_1851.jpg
# done printing for  img_100788.jpg
# done printing for  img_77750.jpg
# done printing for  img_70914.jpg
# done printing for  img_8000.jpg
# done printing for  img_77094.jpg
# done printing for  img_100592.jpg
# done printing for  img_11027.jpg
# done printing for  img_7238.jpg
# done printing for  img_20116.jpg
# done printing for  img_65891.jpg
# done printing for  img_4752.jpg
# done printing for  img_33980.jpg
# done printing for  img_37544.jpg
# done printing for  img_7485.jpg
# done printing for  img_31518.jpg

# %%
# !pip install pickle5
import pickle5 
test_dataframe.to_pickle("/content/gdrive/MyDrive/project/knn_test.pkl")
# Out:
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.11)

# %%
import pandas as pd
test_data1 = pd.read_pickle('/content/gdrive/MyDrive/project/test_data.pkl')
test_data=test_data1.to_numpy()

# %%
image_names=test_data[:,0]
vectors=test_data[:,1]
X_test=array([vectors[i].reshape(128,128,3) for i in range(len(vectors))])

# %%
plt.imshow(X_test[10])
plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %% [markdown]
# ##Data Visualization

# %%
import os
from numpy import *
from numpy import expand_dims
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import pandas as pd
data = pd.read_pickle('/content/gdrive/MyDrive/project/3_channel_128.pkl')
# data = pd.read_pickle('/content/gdrive/MyDrive/project/last_not_mean_centred.pkl')

# data = pd.read_pickle('/content/gdrive/MyDrive/project/final.pkl')

data1=data.to_numpy()
persons=data1[:,1]
values, counts = unique(persons, return_counts=True) # returns unique values in persons and their respective 
# frequency of occurence
for i in range(data1.shape[0]):
    data1[i][3]=int(data1[i][3])

# %%
get_val_row_indices=where(persons=='p050')[0]
get_val_row_indices=append(get_val_row_indices,where(persons=='p015')[0])
get_val_row_indices=append(get_val_row_indices,where(persons=='p022')[0])
get_val_row_indices=append(get_val_row_indices,where(persons=='p056')[0])
val_data=array([data1[i] for i in get_val_row_indices]) # val_data is the v0.000001alidation data

# Ensuring that the validation data is randomly shuffed
random.shuffle(val_data)
# get_train_row_indices= where((persons!= 'p045') & (persons!='p072') & (persons!='p066') & (persons!='p035') & (persons!='p039') & (persons!='p041') )[0]
get_train_row_indices= where((persons!= 'p050') & (persons!='p015')  & (persons!='p022') & (persons!='p056') )[0]

print(len(get_train_row_indices),len(val_data))
train_data=array([data1[i] for i in get_train_row_indices]) # train_data is the training data
# Ensuring that the train data is randomly shuffed many times so as to make the training easier
random.shuffle(train_data)
# Out:
# 18732 3692

# %%
#@title
import seaborn as sns
dataset = pd.read_csv('/content/gdrive/MyDrive/project/driver_imgs_list.csv')
# npdataset = dataset.to_numpy()
# persons1=npdataset[:,1]
values1=array(['p050', 'p015', 'p022', 'p056'])
# Plot figure size
plt.figure(figsize = (5,5))
for i in range(len(values1)):
  df=dataset.loc[dataset['subject'] == values1[i] ]
  if i!=0:
    frames = [df1, df]
    df = pd.concat(frames)
  df1=df
# Count the number of images per category
sns.countplot(x = 'classname', data =df)
# Change the Axis names
plt.ylabel('Count')
plt.title('Categories Distribution of Validation data')
# Show plot
plt.show()
print(df)

values1=array(['p002','p012','p014', 'p016', 'p021', 'p024',
       'p026','p035','p039','p041', 'p042', 'p045', 'p047', 'p049','p051',
       'p052', 'p061', 'p066', 'p064','p072',
       'p075', 'p081'], dtype=object)
# Plot figure size
plt.figure(figsize = (5,5))
for i in range(len(values1)):
  df=dataset.loc[dataset['subject'] == values1[i] ]
  if i!=0:
    frames = [df1, df]
    df = pd.concat(frames)
  df1=df
# Count the number of images per category
sns.countplot(x = 'classname', data =df)
# Change the Axis names
plt.ylabel('Count')
plt.title('Categories Distribution of Train data')
# Show plot
plt.show()
print(df)

# %%
size = 128
batch_size = 64
channels = 3

# %%
#@title plotting image
data2=array([int(data1[0][2][i]) for i in range(size*size*channels)])
test_image=data2.reshape(size,size,channels)
test_image = test_image[...,::-1] # Added
plt.imshow(test_image)
plt.axis('off')
# data2=array([int(data1[0][2][i]*255) for i in range(size*size*channels)])
# plt.imshow(data2.reshape(size,size), cmap="gray")
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
#@title
for i in range(len(counts)):
  print("{} {}".format(values[i],counts[i]))

# %%
#@title
import seaborn as sns
dataset = pd.read_csv('/content/gdrive/MyDrive/project/driver_imgs_list.csv')
npdataset = dataset.to_numpy()
# Plot figure size
plt.figure(figsize = (5,5))
for driver in values:
  new_data_set=dataset.loc[dataset['subject'] == driver]
  # Count the number of images per category
  sns.countplot(x = 'classname', data =new_data_set)
  # Change the Axis names
  plt.ylabel('Count')
  plt.title('Categories Distribution for {}'.format(driver))
  # Show plot
  plt.show()

# %%
#@title
plt.figure(figsize = (5,5))
# Count the number of images per category
sns.countplot(x = 'classname', data =dataset)
# Change the Axis names
plt.ylabel('Count')

plt.title('Categories Distribution')
# Show plot
plt.show()


# Epoch 00011: val_loss improved from 1.16446 to 1.08469, saving model to model1.h5
# Epoch 12/25
# 569/569 [==============================] - 5s 9ms/step - loss: 0.0286 - accuracy: 0.9926 - val_loss: 1.1445 - val_accuracy: 0.7804

# Epoch 00012: val_loss did not improve from 1.08469
# Epoch 13/25
# 569/569 [==============================] - 5s 9ms/step - loss: 0.0138 - accuracy: 0.9959 - val_loss: 1.1746 - val_accuracy: 0.7811

# Epoch 00013: val_loss did not improve from 1.08469
# Epoch 14/25
# 569/569 [==============================] - 5s 9ms/step - loss: 0.0180 - accuracy: 0.9949 - val_loss: 1.1269 - val_accuracy: 0.8020
# 99 - accuracy: 0.9888 - val_loss: 1.0847 - val_accuracy: 0.7906

# %% [markdown]
# ##Splitting data to train and test without Data leakage

# %%
# pip install np-utils
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import cv2
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, Convolution2D
from keras.utils import np_utils
from keras.preprocessing import image 
from keras.layers.normalization import BatchNormalization
from keras import optimizers
import h5py

# %%
from keras.utils import np_utils
# !pip install pickle5
# import pickle5 as pickle
X_train=train_data[:,2]
X_train=array([X_train[i].reshape(size,size,channels)[...,::-1] for i in range(len(X_train))])
# X_train=array([X_train[i].reshape(size,size,channels) for i in range(len(X_train))])

y_train=train_data[:,3]  # The training class labels

X_val=val_data[:,2]
X_val=array([X_val[i].reshape(size,size,channels)[...,::-1] for i in range(len(X_val))])
# X_val=array([X_val[i].reshape(size,size,channels) for i in range(len(X_val))])

y_val=val_data[:,3]  # The validation class labels

y_train = np_utils.to_categorical(y_train, 10)
y_val = np_utils.to_categorical(y_val, 10)
# filename = "training.pkl"
# with open(filename, 'wb') as filehandler:
#     pickle.dump(X_train, filehandler)

# %%
#@title
plt.imshow(X_train[108])
plt.show()
plt.imshow(X_val[108])
plt.show()
print(len(X_train),len(X_val))

# %%
#@title
# !pip3 install tensorflow-gpu

# %%
#@title
# !nvidia-smi

# %% [markdown]
# # Starting implementation of a Simple CNN

# %%
#@title Simple CNN
def create_model_v2():
    # Optimised Vanilla CNN model
    model = Sequential()

    ## CNN 1
    model.add(Conv2D(32,(3,3),activation='relu',padding='same',input_shape=( size, size, channels)))
    model.add(BatchNormalization())
    model.add(Conv2D(32,(3,3),activation='relu',padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2),padding='same'))
    model.add(Dropout(0.2))

    ## CNN 2
    model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2),padding='same'))
    model.add(Dropout(0.45))

    ## CNN 3
    model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2,2),padding='same'))
    model.add(Dropout(0.65))

    ## Output
    model.add(Flatten())
    model.add(Dense(512,activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.7))

    model.add(Dense(256,activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.8))

    model.add(Dense(128,activation='relu'))
    model.add(BatchNormalization())

    model.add(Dense(10,activation='softmax'))

    return model

# %%
#@title
from keras.preprocessing.image import ImageDataGenerator

# train_datagen =  ImageDataGenerator(brightness_range=[0.6,1.4],shear_range=5,
#                                     zoom_range=0.4, rotation_range=30, 
#                                     width_shift_range=0.5,height_shift_range=0.5)

train_datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.4,
    height_shift_range=0.4,
    )

train_generator = train_datagen.flow(
    X_train,
    y_train,
    batch_size=batch_size
)

# validation_datagen = ImageDataGenerator(
#     rescale=1./255,

#     )
    # rotation_range=11,
    # shear_range=0.1,
    # zoom_range=0.15,
    # width_shift_range=0.15,
    # height_shift_range=0.15,
    # brightness_range = (0.85,1.15)

# validation_generator = validation_datagen.flow(
#     X_val,
#     y_val,
#     batch_size=batch_size
# )

# %%
#@title
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

callbacks = [
    EarlyStopping(patience=12, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint('model1.h5', verbose=1, save_best_only=True, save_weights_only=True) ]
model=create_model_v2()
model.compile(
  loss='categorical_crossentropy',
  optimizer=optimizers.SGD(learning_rate=0.1),
  metrics=['accuracy']
)
model.summary()

# %%
#@title
history_v2 =model.fit(
    train_generator,
    steps_per_epoch=len(X_train) // batch_size, 
    validation_data=(X_val,y_val),
    epochs=25,
    callbacks=callbacks )


# history_v2 =model_v2.fit(X_train,y_train, validation_data=(X_val,y_val),epochs=10, callbacks=callbacks)

# %% [markdown]
# #### Plotting curves of VALIDATION and TRAIN accuracies and losses

# %%
def plot_train_history(history):
    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'])
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'])
    plt.show()
# plot_train_history(history_v2)

# %% [markdown]
# ## Implementing Pre-Trained Models

# %% [markdown]
# ##VGG-16

# %%
from keras.applications.vgg16 import preprocess_input
import pandas as pd                        
X_val1=preprocess_input(X_val)

# %%
import shutil
shutil.copy("/content/knn_val.pkl","/content/gdrive/MyDrive/project/knn_val.pkl")
# Out:
# '/content/gdrive/MyDrive/project/knn_val.pkl'

# %%
#@title 0.43 log loss

from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential

# re-size all the images to this
# add preprocessing layer to the front of VGG
vgg16_input = Input(shape = (size,size,channels))

vgg = VGG16(input_tensor=vgg16_input, weights='imagenet', include_top=False)

for layer in vgg.layers:
	layer.trainable = False

train_datagen=ImageDataGenerator(brightness_range=[0.7,1.3],shear_range=10,
                                    zoom_range=0.3, rotation_range=10, 
                                    width_shift_range=0.1,height_shift_range=0.1,
                                     preprocessing_function=preprocess_input,
                                )


train_generator = train_datagen.flow(
    X_train,
    y_train,
    batch_size=batch_size
)

x = vgg(vgg16_input)
x = Flatten()(x)
x = Dropout(0.3)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.6)(x)
x = Dense(128, activation='relu')(x)
prediction = Dense(10, activation='softmax')(x)

# create a model object
model = Model(inputs = vgg16_input, outputs = prediction )

# our layers - you can add more if you want
# x = Flatten()(vgg.output)

# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer=optimizers.SGD(learning_rate=1e-2, momentum=0.9),
  metrics=['accuracy']
)

model.summary()
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

callbacks = [
    EarlyStopping(patience=9, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=1e-9, verbose=1),
    ModelCheckpoint('vgg_finetune.h5', verbose=1, save_best_only=True, save_weights_only=True) ]

# %%
model.load_weights('/content/gdrive/MyDrive/project/vgg_0.36__preproccessed_loss.h5')

# %%
for layer in vgg.layers:
	layer.trainable = True
for layer in vgg.layers:
	print("{}: {}".format(layer, layer.trainable))

# %%
train_datagen=ImageDataGenerator(brightness_range=[0.8,1.2],
                                    zoom_range=0.3, rotation_range=20, 
                                    width_shift_range=0.1,height_shift_range=0.1,
                                     preprocessing_function=preprocess_input,
                                )

train_generator = train_datagen.flow(
    X_train,
    y_train,
    batch_size=batch_size)


model.summary()

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer=optimizers.Adagrad(learning_rate=2e-4,decay=1e-3/10),
  metrics=['accuracy']
)

a = model.fit(
  train_generator,
  steps_per_epoch=len(X_train) // batch_size, 
  validation_data=(X_val1,y_val),
  epochs=25,callbacks=callbacks )

# %%
#@title Default title text
import keras,os
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

model = Sequential()
model.add(Conv2D(input_shape=(size,size,channels),filters=16,kernel_size=(3,3),padding="same", activation="relu"))
# model.add(BatchNormalization())
model.add(Conv2D(filters=16,kernel_size=(3,3),padding="same", activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.1))

model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
# model.add(BatchNormalization())
model.add(Conv2D(filters=32, kernel_size=(3,3), padding="same", activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.2))


model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
# model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.3))


model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
# model.add(BatchNormalization())

model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
# model.add(BatchNormalization())

model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
# model.add(BatchNormalization())

model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.4))


model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
# model.add(BatchNormalization())

model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
# model.add(BatchNormalization())

model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
# model.add(BatchNormalization())

model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.5))


model.add(Flatten())
model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())

model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
# model.add(BatchNormalization())

model.add(Dropout(0.5))

# Code above loads pre-trained data and
model.add(Dense(10, activation='softmax'))
# Learning rate is changed to 0.001
model.compile(optimizers.SGD(learning_rate=2.5e-2,momentum=0.9), loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()

# %%
#@title Default title text
callbacks = [
    EarlyStopping(patience=20, verbose=1),
    ModelCheckpoint('vgg3.h5', verbose=1, save_best_only=True, save_weights_only=True) ]
    # ReduceLROnPlateau(factor=0.1, patience=3, min_lr=1e-9, verbose=1),

model.fit(
  X_train,y_train,
  steps_per_epoch=len(X_train) // batch_size,
  validation_data=(X_val,y_val),
  epochs=150,callbacks=callbacks)

# %%
model.load_weights('vgg3.h5')
from sklearn.metrics import log_loss
predictions_valid = model.predict(X_val1, batch_size=batch_size, verbose=1)
score = log_loss(y_val, predictions_valid)
print('Score log_loss: ', score)
# Out:
# 58/58 [==============================] - 3s 38ms/step
# Score log_loss:  0.43483777281079666

# %%
plot_train_history(a)

# %% [markdown]
# # Resnet

# %%
# !pip install resnet

# %%
# !pip install Keras-Applications

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import ResNet50
from keras.applications.resnet50 import preprocess_input


X_train1=preprocess_input(X_train)
X_val1=preprocess_input(X_val)

# %%
baseModel = ResNet50(weights="imagenet", include_top=False, input_tensor=Input(shape=(128, 128, 3)))
baseModel.summary()
# construct the head of the model that will be placed on top of the
# the base model
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(4, 4))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(512, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(10, activation="softmax")(headModel)
# # place the head FC model on top of the base model (this will become
# # the actual model we will train)
model = Model(inputs=baseModel.input, outputs=headModel)
# # loop over all layers in the base model and freeze them so they will
# # *not* be updated during the training process

# for layer in baseModel.layers:
# 	layer.trainable = False
model.summary()

# %%
batch_size=32
train_datagen=ImageDataGenerator(brightness_range=[0.4,1.6],shear_range=10,
                                    zoom_range=0.5, rotation_range=20, 
                                    width_shift_range=0.25,height_shift_range=0.25,
                                     preprocessing_function=preprocess_input,
                                )

train_generator = train_datagen.flow(
    X_train,
    y_train,
    batch_size=batch_size
)

from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint('resnet1.h5', verbose=1, save_best_only=True, save_weights_only=True) ]
for layer in baseModel.layers:
	layer.trainable = True

# %%
for layer in baseModel.layers:
	layer.trainable = True
# for layer in baseModel.layers:
	# print("{}: {}".format(layer, layer.trainable))

model.compile(
  loss='categorical_crossentropy',
  optimizer=optimizers.Adadelta(learning_rate=0.002) ,
  metrics=['accuracy']
)
model.summary()

# %%
# train the model
H = model.fit(
	train_generator,
	steps_per_epoch=len(X_train1) // batch_size,
	validation_data=(X_val1,y_val),epochs=30, callbacks=callbacks)

# %% [markdown]
# # MobileNet

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications.mobilenet import  preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential

X_train1=preprocess_input(X_train)
X_val1=preprocess_input(X_val)

# %%
baseModel = MobileNet(weights="imagenet", include_top=False, input_shape=(128, 128, 3) )
baseModel.summary()
# construct the head of the model that will be placed on top of the
# the base model
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(4, 4))(headModel)
headModel = Flatten()(headModel)
headModel = Dense(256, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(256, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(10, activation="softmax")(headModel)
# # place the head FC model on top of the base model (this will become
# # the actual model we will train)
model = Model(inputs=baseModel.input, outputs=headModel)
# # loop over all layers in the base model and freeze them so they will
# # *not* be updated during the training process

for layer in baseModel.layers:
	layer.trainable = True

# for layer in baseModel.layers:
	# print("{}: {}".format(layer, layer.trainable))

model.compile(
  loss='categorical_crossentropy',
  optimizer=optimizers.SGD(learning_rate=0.001) ,
  metrics=['accuracy']
)
model.summary()

# %%
model.load_weights("/content/gdrive/MyDrive/project/mobilenet_0.398_loss_preprocessed.h5")

# %%
for layer in baseModel.layers:
	layer.trainable = True
batch_size=64
train_datagen=ImageDataGenerator(brightness_range=[0.4,1.6],shear_range=10,
                                    zoom_range=0.5, rotation_range=20, 
                                    width_shift_range=0.25,height_shift_range=0.25,
                                     preprocessing_function=preprocess_input,
                                )

train_generator = train_datagen.flow(
    X_train,
    y_train,
    batch_size=batch_size
)

from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.000001, verbose=1),
    ModelCheckpoint('mobilenet2.h5', verbose=1, save_best_only=True, save_weights_only=True) ]

# %%
import shutil
shutil.copy("/content/mobilenet2.h5","/content/gdrive/MyDrive/project/mobilenet_0.3407_loss_preprocessed.h5")

# %%
model.load_weights("mobilenet2.h5")
model.compile(
  loss='categorical_crossentropy',
  optimizer=optimizers.Adagrad(learning_rate=0.0001) ,
  metrics=['accuracy']
)

# %%
# train the model
H = model.fit(
	train_generator,
	steps_per_epoch=len(X_train1) // batch_size,
	validation_data=(X_val1,y_val),epochs=30, callbacks=callbacks)
# Out:
# Epoch 1/30
# 292/292 [==============================] - 93s 308ms/step - loss: 0.1492 - accuracy: 0.9545 - val_loss: 0.3418 - val_accuracy: 0.9049
#
# Epoch 00001: val_loss did not improve from 0.34047
# Epoch 2/30
# 292/292 [==============================] - 89s 305ms/step - loss: 0.1450 - accuracy: 0.9563 - val_loss: 0.3781 - val_accuracy: 0.8976
#
# Epoch 00002: val_loss did not improve from 0.34047
# Epoch 3/30
# 292/292 [==============================] - 89s 305ms/step - loss: 0.1425 - accuracy: 0.9580 - val_loss: 0.3576 - val_accuracy: 0.8984
#
# Epoch 00003: val_loss did not improve from 0.34047
# Epoch 4/30
#  10/292 [>.............................] - ETA: 1:24 - loss: 0.1336 - accuracy: 0.9625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-eb081f244ad1> in <module>()
#       3         train_generator,
#       4         steps_per_epoch=len(X_train1) // batch_size,
# ----> 5 	validation_data=(X_val1,y_val),epochs=30, callbacks=callbacks)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3023     return graph_function._call_flat(
# -> 3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#    3026   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1959       # No tape is watching; skip to running the function.
#    1960       return self._build_call_outputs(self._inference_function.call(
# -> 1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#    1963         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
